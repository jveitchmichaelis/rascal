# %%
from astropy.io import fits
import astropy.units as u
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from scipy.signal import find_peaks
from scipy.signal import resample

from rascal.calibrator import Calibrator
from rascal.util import refine_peaks

# %matplotlib inline
# Out:
# /Users/marcolam/git/rascal/rascal/calibrator.py:21: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
data = fits.open('data_lt_sprat/v_a_20190516_57_1_0_1.fits')[0].data

# %%
plt.figure(1, figsize=(16,5))
plt.imshow(np.log(data.data), aspect='auto', origin='lower')
plt.tight_layout()
# Out:
# <ipython-input-3-a0c827e8d172>:2: RuntimeWarning: invalid value encountered in log
#   plt.imshow(np.log(data.data), aspect='auto', origin='lower')

# %%
spectrum = np.median(data[110:120], axis=0)

peaks, _ = find_peaks(spectrum, height=500, distance=5, threshold=None)
peaks_refined = refine_peaks(spectrum, peaks, window_width=5)

atlas = [
    4193.5, 4385.77, 4500.98, 4524.68, 4582.75, 4624.28, 4671.23, 4697.02,
    4734.15, 4807.02, 4921.48, 5028.28, 5618.88, 5823.89, 5893.29, 5934.17,
    6182.42, 6318.06, 6472.841, 6595.56, 6668.92, 6728.01, 6827.32, 6976.18,
    7119.60, 7257.9, 7393.8, 7584.68, 7642.02, 7740.31, 7802.65, 7887.40,
    7967.34, 8057.258
]
element = ['Xe'] * len(atlas)

# %%
c = Calibrator(peaks_refined, spectrum)
               
c.set_calibrator_properties(num_pix=len(spectrum),
                            plotting_library='matplotlib',
                            log_level='info') 
c.set_hough_properties(num_slopes=5000,
                       xbins=100,
                       ybins=100,
                       min_wavelength=3500.,
                       max_wavelength=8000.,
                       range_tolerance=500.,
                       linearity_tolerance=50)
c.load_user_atlas(elements=element,
                  wavelengths=atlas,
                  constrain_poly=True)

c.set_ransac_properties(sample_size=5,
                        top_n_candidate=5,
                        linear=True,
                        filter_close=True,
                        ransac_tolerance=5,
                        candidate_weighted=True,
                        hough_weight=1.0)
c.do_hough_transform()
# Out:
# INFO:rascal.calibrator:num_pix is set to None.
# INFO:rascal.calibrator:pixel_list is set to None.
# INFO:rascal.calibrator:Plotting with matplotlib.
# INFO:rascal.calibrator:num_pix is set to 1024.
# INFO:rascal.calibrator:pixel_list is set to None.
# INFO:rascal.calibrator:Plotting with matplotlib.

# %%
c.plot_arc()

# %%
polyfit_coeff, rms, residual, peak_utilisation = c.fit(max_tries=500)

c.plot_fit(polyfit_coeff,
           plot_atlas=True,
           log_spectrum=False,
           tolerance=10.,
           renderer='notebook')

rms = np.sqrt(np.sum(residual**2 / len(residual)))

print("Stdev error: {} A".format(np.abs(residual).std()))
print("Peaks utilisation rate: {}%".format(peak_utilisation*100))
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=500.0), HTML(value='')))
# INFO:rascal.calibrator:Peak at: 4499.369274428459 A
# INFO:rascal.calibrator:- matched to 4500.98 A
# INFO:rascal.calibrator:Peak at: 4526.616088722797 A
# INFO:rascal.calibrator:- matched to 4524.68 A
# INFO:rascal.calibrator:Peak at: 4582.440108016337 A
# INFO:rascal.calibrator:- matched to 4582.75 A
# INFO:rascal.calibrator:Peak at: 4622.3886412197935 A
# INFO:rascal.calibrator:- matched to 4624.28 A
# INFO:rascal.calibrator:Peak at: 4670.375830645995 A
# INFO:rascal.calibrator:- matched to 4671.23 A
# INFO:rascal.calibrator:Peak at: 4699.208259324296 A
# INFO:rascal.calibrator:- matched to 4697.02 A
# INFO:rascal.calibrator:Peak at: 4733.792068577259 A
# INFO:rascal.calibrator:- matched to 4734.15 A
# INFO:rascal.calibrator:Peak at: 4771.915166508619 A
# INFO:rascal.calibrator:Peak at: 4808.8095108837115 A
# INFO:rascal.calibrator:- matched to 4807.02 A
# INFO:rascal.calibrator:Peak at: 4837.618382091219 A
# INFO:rascal.calibrator:Peak at: 4921.090669780773 A
# INFO:rascal.calibrator:- matched to 4921.48 A
# INFO:rascal.calibrator:Peak at: 4972.652655436223 A
# INFO:rascal.calibrator:Peak at: 5029.36241694935 A
# INFO:rascal.calibrator:- matched to 5028.28 A
# INFO:rascal.calibrator:Peak at: 5075.21557628325 A
# INFO:rascal.calibrator:Peak at: 5113.2164018959065 A
# INFO:rascal.calibrator:Peak at: 5194.813582332828 A
# INFO:rascal.calibrator:Peak at: 5195.977982147684 A
# INFO:rascal.calibrator:Peak at: 5258.345097553189 A
# INFO:rascal.calibrator:Peak at: 5297.909349643089 A
# INFO:rascal.calibrator:Peak at: 5343.7768108385435 A
# INFO:rascal.calibrator:Peak at: 5375.296421054995 A
# INFO:rascal.calibrator:Peak at: 5406.708145060027 A
# INFO:rascal.calibrator:Peak at: 5508.138149506229 A
# INFO:rascal.calibrator:Peak at: 5539.372741331486 A
# INFO:rascal.calibrator:Peak at: 5572.832090958742 A
# INFO:rascal.calibrator:Peak at: 5617.856431485332 A
# INFO:rascal.calibrator:- matched to 5618.88 A
# INFO:rascal.calibrator:Peak at: 5662.967950198458 A
# INFO:rascal.calibrator:Peak at: 5701.827989167381 A
# INFO:rascal.calibrator:Peak at: 5727.1549051348065 A
# INFO:rascal.calibrator:Peak at: 5754.752789567917 A
# INFO:rascal.calibrator:Peak at: 5823.656206345813 A
# INFO:rascal.calibrator:- matched to 5823.89 A
# INFO:rascal.calibrator:Peak at: 5865.999243265182 A
# INFO:rascal.calibrator:Peak at: 5891.964319093202 A
# INFO:rascal.calibrator:- matched to 5893.29 A
# INFO:rascal.calibrator:Peak at: 5932.949638840049 A
# INFO:rascal.calibrator:- matched to 5934.17 A
# INFO:rascal.calibrator:Peak at: 5980.098609914776 A
# INFO:rascal.calibrator:Peak at: 6033.27948415267 A
# INFO:rascal.calibrator:Peak at: 6109.9990154180705 A
# INFO:rascal.calibrator:Peak at: 6181.594654546459 A
# INFO:rascal.calibrator:- matched to 6182.42 A
# INFO:rascal.calibrator:Peak at: 6273.991155684136 A
# INFO:rascal.calibrator:Peak at: 6304.436165200872 A
# INFO:rascal.calibrator:Peak at: 6320.070796212782 A
# INFO:rascal.calibrator:- matched to 6318.06 A
# INFO:rascal.calibrator:Peak at: 6474.538460120264 A
# INFO:rascal.calibrator:- matched to 6472.841 A
# INFO:rascal.calibrator:Peak at: 6528.469358524266 A
# INFO:rascal.calibrator:Peak at: 6596.178753170274 A
# INFO:rascal.calibrator:- matched to 6595.56 A
# INFO:rascal.calibrator:Peak at: 6668.390297499642 A
# INFO:rascal.calibrator:- matched to 6668.92 A
# INFO:rascal.calibrator:Peak at: 6727.298829445117 A
# INFO:rascal.calibrator:- matched to 6728.01 A
# INFO:rascal.calibrator:Peak at: 6828.6904420513665 A
# INFO:rascal.calibrator:- matched to 6827.32 A
# INFO:rascal.calibrator:Peak at: 6975.604212831945 A
# INFO:rascal.calibrator:- matched to 6976.18 A
# INFO:rascal.calibrator:Peak at: 6881.827819699866 A
# INFO:rascal.calibrator:Peak at: 6924.048775936293 A
# INFO:rascal.calibrator:Peak at: 6976.54608273335 A
# INFO:rascal.calibrator:- matched to 6976.18 A
# INFO:rascal.calibrator:Peak at: 7119.308347008911 A
# INFO:rascal.calibrator:- matched to 7119.6 A
# INFO:rascal.calibrator:Peak at: 7288.313200088602 A
# INFO:rascal.calibrator:Peak at: 7320.661514988551 A
# INFO:rascal.calibrator:Peak at: 7391.997792267688 A
# INFO:rascal.calibrator:- matched to 7393.8 A
# INFO:rascal.calibrator:Peak at: 7476.739553012704 A
# INFO:rascal.calibrator:Peak at: 7585.204203849691 A
# INFO:rascal.calibrator:- matched to 7584.68 A
# INFO:rascal.calibrator:Peak at: 7643.039954290248 A
# INFO:rascal.calibrator:- matched to 7642.02 A
# INFO:rascal.calibrator:Peak at: 7800.537409683989 A
# INFO:rascal.calibrator:- matched to 7802.65 A
# INFO:rascal.calibrator:Peak at: 7887.619737250271 A
# INFO:rascal.calibrator:- matched to 7887.4 A
# INFO:rascal.calibrator:Peak at: 7967.482105079863 A
# INFO:rascal.calibrator:- matched to 7967.34 A
# INFO:rascal.calibrator:Peak at: 8058.345502399684 A
# INFO:rascal.calibrator:- matched to 8057.258 A
# Stdev error: 0.6276442090587149 A
# Peaks utilisation rate: 358.8235294117647%

# %% [markdown]
# # Now, we refine this set of polynomial coefficients and apply to a different night of arc

# %%
data2 = fits.open('data_lt_sprat/v_a_20200409_39_1_0_1.fits')[0].data
spectrum2 = np.median(data2[105:110], axis=0)

peaks2, _ = find_peaks(spectrum2, height=600, distance=5, threshold=None)
peaks_refined2 = refine_peaks(spectrum2, peaks2, window_width=5)

# %% [markdown]
# ## Fit using the polynomial fit coefficients as the first best guess

# %%
c2 = Calibrator(peaks_refined2, spectrum2)
               
c2.set_calibrator_properties(num_pix=len(spectrum2),
                            plotting_library='matplotlib',
                            log_level='info') 
c2.set_hough_properties(num_slopes=5000,
                       xbins=100,
                       ybins=100,
                       min_wavelength=3500.,
                       max_wavelength=8000.,
                       range_tolerance=500.,
                       linearity_tolerance=50)
c2.load_user_atlas(elements=element,
                  wavelengths=atlas,
                  constrain_poly=True)

c2.set_ransac_properties(sample_size=5,
                        top_n_candidate=5,
                        linear=True,
                        filter_close=True,
                        ransac_tolerance=5,
                        candidate_weighted=True,
                        hough_weight=1.0)
c2.do_hough_transform()

polyfit_coeff2, rms2, residual2, peak_utilisation2 = c2.fit(max_tries=500, fit_coeff=polyfit_coeff)

c2.plot_fit(polyfit_coeff2,
            plot_atlas=True,
            log_spectrum=False,
            tolerance=10.,
            renderer='notebook')

rms2 = np.sqrt(np.sum(residual2**2 / len(residual2)))

print("Stdev error: {} A".format(np.abs(residual2).std()))
print("Peaks utilisation rate: {}%".format(peak_utilisation2*100))
# Out:
# INFO:rascal.calibrator:num_pix is set to None.
# INFO:rascal.calibrator:pixel_list is set to None.
# INFO:rascal.calibrator:Plotting with matplotlib.
# INFO:rascal.calibrator:num_pix is set to 1024.
# INFO:rascal.calibrator:pixel_list is set to None.
# INFO:rascal.calibrator:Plotting with matplotlib.
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=500.0), HTML(value='')))
# INFO:rascal.calibrator:Peak at: 4499.92310164824 A
# INFO:rascal.calibrator:- matched to 4500.98 A
# INFO:rascal.calibrator:Peak at: 4526.595799027791 A
# INFO:rascal.calibrator:- matched to 4524.68 A
# INFO:rascal.calibrator:Peak at: 4622.749923831622 A
# INFO:rascal.calibrator:- matched to 4624.28 A
# INFO:rascal.calibrator:Peak at: 4670.6052391310195 A
# INFO:rascal.calibrator:- matched to 4671.23 A
# INFO:rascal.calibrator:Peak at: 4697.7935338335155 A
# INFO:rascal.calibrator:- matched to 4697.02 A
# INFO:rascal.calibrator:Peak at: 4733.724958636642 A
# INFO:rascal.calibrator:- matched to 4734.15 A
# INFO:rascal.calibrator:Peak at: 4808.894342009149 A
# INFO:rascal.calibrator:- matched to 4807.02 A
# INFO:rascal.calibrator:Peak at: 4837.407379923171 A
# INFO:rascal.calibrator:Peak at: 4920.665894767836 A
# INFO:rascal.calibrator:- matched to 4921.48 A
# INFO:rascal.calibrator:Peak at: 5029.196389201481 A
# INFO:rascal.calibrator:- matched to 5028.28 A
# INFO:rascal.calibrator:Peak at: 5373.195994879114 A
# INFO:rascal.calibrator:Peak at: 5403.645175592644 A
# INFO:rascal.calibrator:Peak at: 5431.265716301064 A
# INFO:rascal.calibrator:Peak at: 5508.040687203765 A
# INFO:rascal.calibrator:Peak at: 5542.506597903266 A
# INFO:rascal.calibrator:Peak at: 5575.748717029359 A
# INFO:rascal.calibrator:Peak at: 5619.035809802628 A
# INFO:rascal.calibrator:- matched to 5618.88 A
# INFO:rascal.calibrator:Peak at: 5708.303961820888 A
# INFO:rascal.calibrator:Peak at: 5725.653972318294 A
# INFO:rascal.calibrator:Peak at: 5824.365411904309 A
# INFO:rascal.calibrator:- matched to 5823.89 A
# INFO:rascal.calibrator:Peak at: 5889.673013711089 A
# INFO:rascal.calibrator:- matched to 5893.29 A
# INFO:rascal.calibrator:Peak at: 5934.138947825061 A
# INFO:rascal.calibrator:- matched to 5934.17 A
# INFO:rascal.calibrator:Peak at: 5979.702740371973 A
# INFO:rascal.calibrator:Peak at: 6034.339184697175 A
# INFO:rascal.calibrator:Peak at: 6110.451137475551 A
# INFO:rascal.calibrator:Peak at: 6181.269886402943 A
# INFO:rascal.calibrator:- matched to 6182.42 A
# INFO:rascal.calibrator:Peak at: 6320.0256280800895 A
# INFO:rascal.calibrator:- matched to 6318.06 A
# INFO:rascal.calibrator:Peak at: 6421.844062964612 A
# INFO:rascal.calibrator:Peak at: 6486.92971670443 A
# INFO:rascal.calibrator:Peak at: 6475.935228841197 A
# INFO:rascal.calibrator:- matched to 6472.841 A
# INFO:rascal.calibrator:Peak at: 6501.304526097771 A
# INFO:rascal.calibrator:Peak at: 6539.376725225567 A
# INFO:rascal.calibrator:Peak at: 6595.484550239562 A
# INFO:rascal.calibrator:- matched to 6595.56 A
# INFO:rascal.calibrator:Peak at: 6634.794328452435 A
# INFO:rascal.calibrator:Peak at: 6668.313622687655 A
# INFO:rascal.calibrator:- matched to 6668.92 A
# INFO:rascal.calibrator:Peak at: 6726.676596960195 A
# INFO:rascal.calibrator:- matched to 6728.01 A
# INFO:rascal.calibrator:Peak at: 6773.685710411029 A
# INFO:rascal.calibrator:Peak at: 6829.773810557799 A
# INFO:rascal.calibrator:- matched to 6827.32 A
# INFO:rascal.calibrator:Peak at: 6877.140439173881 A
# INFO:rascal.calibrator:Peak at: 6922.96220774709 A
# INFO:rascal.calibrator:Peak at: 6975.2053263626985 A
# INFO:rascal.calibrator:- matched to 6976.18 A
# INFO:rascal.calibrator:Peak at: 7018.362037204202 A
# INFO:rascal.calibrator:Peak at: 7046.93844213597 A
# INFO:rascal.calibrator:Peak at: 7117.985451848468 A
# INFO:rascal.calibrator:- matched to 7119.6 A
# INFO:rascal.calibrator:Peak at: 7287.711070443581 A
# INFO:rascal.calibrator:Peak at: 7319.741032067015 A
# INFO:rascal.calibrator:Peak at: 7390.5469935682795 A
# INFO:rascal.calibrator:- matched to 7393.8 A
# INFO:rascal.calibrator:Peak at: 7479.196684124576 A
# INFO:rascal.calibrator:Peak at: 7588.421683020732 A
# INFO:rascal.calibrator:- matched to 7584.68 A
# INFO:rascal.calibrator:Peak at: 7641.699363512815 A
# INFO:rascal.calibrator:- matched to 7642.02 A
# INFO:rascal.calibrator:Peak at: 7799.390057732493 A
# INFO:rascal.calibrator:- matched to 7802.65 A
# INFO:rascal.calibrator:Peak at: 7886.4507821417465 A
# INFO:rascal.calibrator:- matched to 7887.4 A
# INFO:rascal.calibrator:Peak at: 7966.995645591058 A
# INFO:rascal.calibrator:- matched to 7967.34 A
# INFO:rascal.calibrator:Peak at: 8058.470694392103 A
# INFO:rascal.calibrator:- matched to 8057.258 A
# Stdev error: 1.0577341595116154 A
# Peaks utilisation rate: 270.5882352941177%

# %%
c2.plot_search_space()
